# %%
#prediction of bike rentals using linear regression ML model - by vinayak bhosale

# %%
#importing necessay libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#reding the data set

# %%
df = pd.read_csv("C:\\Users\\Pinky\\Desktop\\python\\new data science\\Data Science with Python\\linear_assignment\\day.csv")

# %%
df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  01-01-2018       1   0     1        0        6           0
# 1        2  02-01-2018       1   0     1        0        0           0
# 2        3  03-01-2018       1   0     1        0        1           1
# 3        4  04-01-2018       1   0     1        0        2           1
# 4        5  05-01-2018       1   0     1        0        3           1
#
#    weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0           2  14.110847  18.18125  80.5833  10.749882     331         654
# 1           2  14.902598  17.68695  69.6087  16.652113     131         670
# 2           1   8.050924   9.47025  43.7273  16.636703     120        1229
# 3           1   8.200000  10.60610  59.0435  10.739832     108        1454
# 4           1   9.305237  11.46350  43.6957  12.522300      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
#checking if there are any null values

# %%
df.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
#checking the info about the data set

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 16 columns):
# instant       730 non-null int64
# dteday        730 non-null object
# season        730 non-null int64
# yr            730 non-null int64
# mnth          730 non-null int64
# holiday       730 non-null int64
# weekday       730 non-null int64
# workingday    730 non-null int64
# weathersit    730 non-null int64
# temp          730 non-null float64
# atemp         730 non-null float64
# hum           730 non-null float64
# windspeed     730 non-null float64
# casual        730 non-null int64
# registered    730 non-null int64
# cnt           730 non-null int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.4+ KB

# %%
#checking the tail of the data set

# %%
df.tail()
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 725      726  27-12-2019       1   1    12        0        4           1
# 726      727  28-12-2019       1   1    12        0        5           1
# 727      728  29-12-2019       1   1    12        0        6           0
# 728      729  30-12-2019       1   1    12        0        0           0
# 729      730  31-12-2019       1   1    12        0        1           1
#
#      weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 725           2  10.420847  11.33210  65.2917  23.458911     247        1867
# 726           2  10.386653  12.75230  59.0000  10.416557     644        2451
# 727           2  10.386653  12.12000  75.2917   8.333661     159        1182
# 728           1  10.489153  11.58500  48.3333  23.500518     364        1432
# 729           2   8.849153  11.17435  57.7500  10.374682     439        2290
#
#       cnt
# 725  2114
# 726  3095
# 727  1341
# 728  1796
# ...

# %%
#from the info we can see dteday is object type we need to convert it to date and time stamp

# %%
df["dteday"] = pd.to_datetime(df["dteday"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 16 columns):
# instant       730 non-null int64
# dteday        730 non-null datetime64[ns]
# season        730 non-null int64
# yr            730 non-null int64
# mnth          730 non-null int64
# holiday       730 non-null int64
# weekday       730 non-null int64
# workingday    730 non-null int64
# weathersit    730 non-null int64
# temp          730 non-null float64
# atemp         730 non-null float64
# hum           730 non-null float64
# windspeed     730 non-null float64
# casual        730 non-null int64
# registered    730 non-null int64
# cnt           730 non-null int64
# dtypes: datetime64[ns](1), float64(4), int64(11)
# memory usage: 91.4 KB

# %%
#dropping the instant column because we already have index

# %%
df.drop("instant",axis=1,inplace=True)

# %%
df.head(2)
# Out:
#       dteday  season  yr  mnth  holiday  weekday  workingday  weathersit  \
# 0 2018-01-01       1   0     1        0        6           0           2
# 1 2018-02-01       1   0     1        0        0           0           2
#
#         temp     atemp      hum  windspeed  casual  registered  cnt
# 0  14.110847  18.18125  80.5833  10.749882     331         654  985
# 1  14.902598  17.68695  69.6087  16.652113     131         670  801

# %%
#plotting the pairplot to check the behaviour

# %%
sns.pairplot(df)

# %%
#checking the correlation

# %%
df.corr()
# Out:
#                   season            yr          mnth   holiday   weekday  \
# season      1.000000e+00 -2.248195e-17  8.310321e-01 -0.010868 -0.003081
# yr         -2.248195e-17  1.000000e+00 -2.470170e-17  0.008195 -0.005466
# mnth        8.310321e-01 -2.470170e-17  1.000000e+00  0.018905  0.009523
# holiday    -1.086804e-02  8.195345e-03  1.890483e-02  1.000000 -0.101962
# weekday    -3.081198e-03 -5.466369e-03  9.522969e-03 -0.101962  1.000000
# workingday  1.376178e-02 -2.945396e-03 -4.687953e-03 -0.252948  0.035800
# weathersit  2.130636e-02 -5.032247e-02  4.561335e-02 -0.034395  0.031112
# temp        3.333607e-01  4.878919e-02  2.190833e-01 -0.028764 -0.000168
# atemp       3.420139e-01  4.721519e-02  2.264302e-01 -0.032703 -0.007539
# hum         2.082196e-01 -1.125471e-01  2.249368e-01 -0.015662 -0.052290
# windspeed  -2.296069e-01 -1.162435e-02 -2.080131e-01  0.006257  0.014283
# casual      2.087373e-01  2.505017e-01  1.212079e-01  0.054055  0.059978
# ...

# %%
#plotting the correlation

# %%
plt.plot(figsize=(10,10))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
df.head(2)
# Out:
#       dteday  season  yr  mnth  holiday  weekday  workingday  weathersit  \
# 0 2018-01-01       1   0     1        0        6           0           2
# 1 2018-02-01       1   0     1        0        0           0           2
#
#         temp     atemp      hum  windspeed  casual  registered  cnt
# 0  14.110847  18.18125  80.5833  10.749882     331         654  985
# 1  14.902598  17.68695  69.6087  16.652113     131         670  801

# %%
#splitting the data into dependent and independent variables

# %%
x = df.drop(['cnt','dteday'],axis=1)
y = df["cnt"]

# %%
from sklearn.model_selection import train_test_split

# %%
 x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=42)

# %%
#building the model

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
#training the model

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#making the predictions

# %%
predictions = model.predict(x_test)

# %%
#checking the intercept and coefficient

# %%
print(model.intercept_)
# Out:
# -4.547473508864641e-12

# %%
print(model.coef_)
# Out:
# [ 4.47437094e-13  2.53130850e-13 -5.03243280e-14  7.42863294e-13
#  -4.53590345e-14 -1.13450160e-13 -2.70013929e-13  9.80751938e-14
#  -3.83200416e-15  7.30578792e-15 -2.19854517e-15  1.00000000e+00
#   1.00000000e+00]

# %%
#plotting the predictions and true y_test values

# %%
plt.scatter(y_test,predictions)
plt.xlabel("Y_test true value")
plt.ylabel("predictions")
# Out:
# Text(0, 0.5, 'predictions')

# %%
#we can the relationship is linear so our model did pretty good in predictions

# %%
from sklearn import metrics

# %%
#checking the errors

# %%
metrics.mean_absolute_error(y_test,predictions)
# Out:
# 1.3065712895172198e-12

# %%
metrics.mean_squared_error(y_test,predictions)
# Out:
# 2.5421047425525166e-24

# %%
np.sqrt(metrics.mean_squared_error(y_test,predictions))
# Out:
# 1.5943979247830563e-12

# %%
#the mean_absolute_error, mean_squared_error, root mean_squared_error are low so we can conclude
#that our model did pretty good and we can go ahead with it
